# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score
import numpy as np

# %%
df = pd.read_excel('../data/Kelulusan.xlsx')
df
# Out:
#      Nim Hasil Sebenarnya Hasil Prediksi
# 0  TI001            lulus          lulus
# 1  TI002            lulus          lulus
# 2  TI003            lulus          lulus
# 3  TI004            lulus    tidak lulus
# 4  TI005            lulus    tidak lulus
# 5  TI006      tidak lulus          lulus
# 6  TI007      tidak lulus    tidak lulus
# 7  TI008      tidak lulus    tidak lulus
# 8  TI009      tidak lulus    tidak lulus
# 9  TI010      tidak lulus    tidak lulus

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nim               10 non-null     object
#  1   Hasil Sebenarnya  10 non-null     object
#  2   Hasil Prediksi    10 non-null     object
# dtypes: object(3)
# memory usage: 372.0+ bytes

# %%
y_true = df["Hasil Sebenarnya"]
y_pred = df["Hasil Prediksi"]

cm = confusion_matrix(y_true, y_pred, labels=["lulus","Tidak lulus"])
print("Confusion Matrix:\n", cm)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["lulus","Tidak lulus"])
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
#  [[3 0]
#  [0 0]]

# %%
y_true = df["Hasil Sebenarnya"]
y_pred = df["Hasil Prediksi"]

# Tentukan label otomatis dari data
labels = sorted(df["Hasil Sebenarnya"].unique())

# Hitung accuracy
accuracy = accuracy_score(y_true, y_pred)

# Hitung precision & recall (macro untuk multi-class)
precision = precision_score(y_true, y_pred, labels=labels, average='macro', zero_division=0)
recall = recall_score(y_true, y_pred, labels=labels, average='macro', zero_division=0)

print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
# Out:
# Accuracy : 0.7
# Precision: 0.7083333333333333
# Recall   : 0.7
